# %%
from neo4j import GraphDatabase
import numpy as np
import pandas as pd
import random

# %% [markdown]
# ## Extracting connected nodes and their relationships

# %%
host = "neo4j+s://neo4j.alzkb.ai"
driver = GraphDatabase.driver(host, auth=None)

# %%
def run_query(query, params={}):
    with driver.session() as session:
        result = session.run(query, params)
        return pd.DataFrame([r.values() for r in result], columns=result.keys())

# %%
def remove_key_value(row, key_to_remove):
    try:
        row.pop(key_to_remove)
    except: 
        return row
    return row

# %%
df = run_query("""
MATCH (s)-[r]->(t)
RETURN labels(s)[0] as source_label, properties(s) as source, type(r) as relationship_type, labels(t)[0] as target_label, properties(t) AS target
""")

# %%
df
# Out:
#         source_label                                             source  \
# 0               Drug  {'commonName': 'Droperidol', 'xrefDrugbank': '...
# 1               Drug  {'commonName': 'Raloxifene', 'xrefDrugbank': '...
# 2               Drug  {'commonName': 'Anagrelide', 'xrefDrugbank': '...
# 3               Drug  {'commonName': 'Amodiaquine', 'xrefDrugbank': ...
# 4               Drug  {'commonName': 'Digoxin', 'xrefDrugbank': 'DB0...
# ...              ...                                                ...
# 1309461      Disease  {'commonName': 'Familial Alzheimer Disease (FA...
# 1309462      Disease  {'commonName': 'Alzheimer's Disease', 'xrefUml...
# 1309463      Disease  {'commonName': 'Familial Alzheimer Disease (FA...
# 1309464      Disease  {'commonName': 'Alzheimer's Disease', 'xrefUml...
# 1309465      Disease  {'commonName': 'Alzheimer's Disease', 'xrefUml...
#
#                    relationship_type target_label  \
# 0                  CHEMICALBINDSGENE         Gene
# 1        CHEMICALINCREASESEXPRESSION         Gene
# 2        CHEMICALINCREASESEXPRESSION         Gene
# 3        CHEMICALINCREASESEXPRESSION         Gene
# 4        CHEMICALDECREASESEXPRESSION         Gene
# ...                              ...          ...
# 1309461    DISEASELOCALIZESTOANATOMY     BodyPart
# 1309462    DISEASELOCALIZESTOANATOMY     BodyPart
# 1309463    DISEASELOCALIZESTOANATOMY     BodyPart
# 1309464    DISEASELOCALIZESTOANATOMY     BodyPart
# 1309465    DISEASELOCALIZESTOANATOMY     BodyPart
#
#                                                     target
# 0        {'typeOfGene': 'protein-coding', 'commonName':...
# 1        {'typeOfGene': 'protein-coding', 'commonName':...
# 2        {'typeOfGene': 'protein-coding', 'commonName':...
# 3        {'typeOfGene': 'protein-coding', 'commonName':...
# 4        {'typeOfGene': 'protein-coding', 'commonName':...
# ...                                                    ...
# 1309461  {'commonName': 'dura mater', 'uri': 'http://jd...
# 1309462  {'commonName': 'forebrain', 'uri': 'http://jdr...
# 1309463  {'commonName': 'spinal cord', 'uri': 'http://j...
# 1309464  {'commonName': 'olfactory nerve', 'uri': 'http...
# 1309465  {'commonName': 'brain', 'uri': 'http://jdr.bio...
#
# [1309466 rows x 5 columns]

# %%
# Getting inverse relationship for gene-gene interactions - not sure if this needs to be explicitly extracted
gene_gene_df = run_query("""
MATCH (s)-[r:GENEINTERACTSWITHGENE]->(t)
RETURN labels(t)[0] as source_label, properties(t) as source, type(r) as relationship_type, labels(s)[0] as target_label, properties(s) AS target
""")

# %%
gene_gene_df
# Out:
#        source_label                                             source  \
# 0              Gene  {'typeOfGene': 'protein-coding', 'commonName':...
# 1              Gene  {'typeOfGene': 'protein-coding', 'commonName':...
# 2              Gene  {'typeOfGene': 'protein-coding', 'commonName':...
# 3              Gene  {'typeOfGene': 'protein-coding', 'commonName':...
# 4              Gene  {'typeOfGene': 'protein-coding', 'commonName':...
# ...             ...                                                ...
# 146996         Gene  {'typeOfGene': 'protein-coding', 'commonName':...
# 146997         Gene  {'typeOfGene': 'protein-coding', 'commonName':...
# 146998         Gene  {'typeOfGene': 'protein-coding', 'commonName':...
# 146999         Gene  {'typeOfGene': 'protein-coding', 'commonName':...
# 147000         Gene  {'typeOfGene': 'protein-coding', 'commonName':...
#
#             relationship_type target_label  \
# 0       GENEINTERACTSWITHGENE         Gene
# 1       GENEINTERACTSWITHGENE         Gene
# 2       GENEINTERACTSWITHGENE         Gene
# 3       GENEINTERACTSWITHGENE         Gene
# 4       GENEINTERACTSWITHGENE         Gene
# ...                       ...          ...
# 146996  GENEINTERACTSWITHGENE         Gene
# 146997  GENEINTERACTSWITHGENE         Gene
# 146998  GENEINTERACTSWITHGENE         Gene
# 146999  GENEINTERACTSWITHGENE         Gene
# 147000  GENEINTERACTSWITHGENE         Gene
#
#                                                    target
# 0       {'typeOfGene': 'protein-coding', 'commonName':...
# 1       {'typeOfGene': 'protein-coding', 'commonName':...
# 2       {'typeOfGene': 'protein-coding', 'commonName':...
# 3       {'typeOfGene': 'protein-coding', 'commonName':...
# 4       {'typeOfGene': 'protein-coding', 'commonName':...
# ...                                                   ...
# 146996  {'typeOfGene': 'protein-coding', 'commonName':...
# 146997  {'typeOfGene': 'protein-coding', 'commonName':...
# 146998  {'typeOfGene': 'protein-coding', 'commonName':...
# 146999  {'typeOfGene': 'protein-coding', 'commonName':...
# 147000  {'typeOfGene': 'protein-coding', 'commonName':...
#
# [147001 rows x 5 columns]

# %%
combined_df = pd.concat([df, gene_gene_df], ignore_index=True)

# %%
# Apply the function to the column
combined_df['source'] = combined_df['source'].apply(lambda row: remove_key_value(row, key_to_remove='uri'))
combined_df['target'] = combined_df['target'].apply(lambda row: remove_key_value(row, key_to_remove='uri'))

# %%
combined_df
# Out:
#         source_label                                             source  \
# 0               Drug  {'commonName': 'Droperidol', 'xrefDrugbank': '...
# 1               Drug  {'commonName': 'Raloxifene', 'xrefDrugbank': '...
# 2               Drug  {'commonName': 'Anagrelide', 'xrefDrugbank': '...
# 3               Drug  {'commonName': 'Amodiaquine', 'xrefDrugbank': ...
# 4               Drug  {'commonName': 'Digoxin', 'xrefDrugbank': 'DB0...
# ...              ...                                                ...
# 1456462         Gene  {'typeOfGene': 'protein-coding', 'commonName':...
# 1456463         Gene  {'typeOfGene': 'protein-coding', 'commonName':...
# 1456464         Gene  {'typeOfGene': 'protein-coding', 'commonName':...
# 1456465         Gene  {'typeOfGene': 'protein-coding', 'commonName':...
# 1456466         Gene  {'typeOfGene': 'protein-coding', 'commonName':...
#
#                    relationship_type target_label  \
# 0                  CHEMICALBINDSGENE         Gene
# 1        CHEMICALINCREASESEXPRESSION         Gene
# 2        CHEMICALINCREASESEXPRESSION         Gene
# 3        CHEMICALINCREASESEXPRESSION         Gene
# 4        CHEMICALDECREASESEXPRESSION         Gene
# ...                              ...          ...
# 1456462        GENEINTERACTSWITHGENE         Gene
# 1456463        GENEINTERACTSWITHGENE         Gene
# 1456464        GENEINTERACTSWITHGENE         Gene
# 1456465        GENEINTERACTSWITHGENE         Gene
# 1456466        GENEINTERACTSWITHGENE         Gene
#
#                                                     target
# 0        {'typeOfGene': 'protein-coding', 'commonName':...
# 1        {'typeOfGene': 'protein-coding', 'commonName':...
# 2        {'typeOfGene': 'protein-coding', 'commonName':...
# 3        {'typeOfGene': 'protein-coding', 'commonName':...
# 4        {'typeOfGene': 'protein-coding', 'commonName':...
# ...                                                    ...
# 1456462  {'typeOfGene': 'protein-coding', 'commonName':...
# 1456463  {'typeOfGene': 'protein-coding', 'commonName':...
# 1456464  {'typeOfGene': 'protein-coding', 'commonName':...
# 1456465  {'typeOfGene': 'protein-coding', 'commonName':...
# 1456466  {'typeOfGene': 'protein-coding', 'commonName':...
#
# [1456467 rows x 5 columns]

# %%
combined_df['relationship_type'].unique()
# Out:
# array(['CHEMICALBINDSGENE', 'CHEMICALINCREASESEXPRESSION',
#        'CHEMICALDECREASESEXPRESSION', 'DRUGINCLASS', 'DRUGTREATSDISEASE',
#        'DRUGCAUSESEFFECT', 'GENEPARTICIPATESINBIOLOGICALPROCESS',
#        'GENEINPATHWAY', 'GENEINTERACTSWITHGENE',
#        'GENEHASMOLECULARFUNCTION', 'GENEASSOCIATEDWITHCELLULARCOMPONENT',
#        'GENEASSOCIATESWITHDISEASE', 'BODYPARTOVEREXPRESSESGENE',
#        'BODYPARTUNDEREXPRESSESGENE', 'SYMPTOMMANIFESTATIONOFDISEASE',
#        'DISEASELOCALIZESTOANATOMY', 'DISEASEASSOCIATESWITHDISEASE'],
#       dtype=object)

# %%
# Rewrite relationship type in Natural language
rels_type = {'GENEINPATHWAY': 'gene in the pathway', 'GENEINTERACTSWITHGENE': 'gene interacts with the gene', \
             'GENEPARTICIPATESINBIOLOGICALPROCESS': 'gene participates in the biological process', \
             'GENEASSOCIATEDWITHCELLULARCOMPONENT': 'gene associated with the cellular component', \
             'GENEHASMOLECULARFUNCTION': 'gene has a molecular function', \
             'GENEASSOCIATESWITHDISEASE': 'gene associates with the disease', \
             'CHEMICALBINDSGENE': 'chemical or drug binds the gene', \
             'CHEMICALINCREASESEXPRESSION': 'chemical or drug increases the gene expression', \
             'CHEMICALDECREASESEXPRESSION': 'chemical or drug decreases the gene expression', \
             'DRUGINCLASS': 'chemical or drug in the drug class', \
             'DISEASELOCALIZESTOANATOMY': 'disease localizes to anatomy or body part', \
             'DISEASEASSOCIATESWITHDISEASE': 'disease associates with another disease', \
             'DRUGCAUSESEFFECT': 'chemical or drug causes effect to the disease', \
             'DRUGTREATSDISEASE': 'chemical or drug treats the disease', \
             'SYMPTOMMANIFESTATIONOFDISEASE': 'symptom manifestation of the disease', \
             'BODYPARTOVEREXPRESSESGENE': 'body part over-expresses the gene', \
             'BODYPARTUNDEREXPRESSESGENE': 'body part under-expresses the gene'}

# %%
combined_df['relationship_type'] = combined_df['relationship_type'].replace(rels_type)
combined_df
# Out:
#         source_label                                             source  \
# 0               Drug  {'commonName': 'Droperidol', 'xrefDrugbank': '...
# 1               Drug  {'commonName': 'Raloxifene', 'xrefDrugbank': '...
# 2               Drug  {'commonName': 'Anagrelide', 'xrefDrugbank': '...
# 3               Drug  {'commonName': 'Amodiaquine', 'xrefDrugbank': ...
# 4               Drug  {'commonName': 'Digoxin', 'xrefDrugbank': 'DB0...
# ...              ...                                                ...
# 1456462         Gene  {'typeOfGene': 'protein-coding', 'commonName':...
# 1456463         Gene  {'typeOfGene': 'protein-coding', 'commonName':...
# 1456464         Gene  {'typeOfGene': 'protein-coding', 'commonName':...
# 1456465         Gene  {'typeOfGene': 'protein-coding', 'commonName':...
# 1456466         Gene  {'typeOfGene': 'protein-coding', 'commonName':...
#
#                                       relationship_type target_label  \
# 0                       chemical or drug binds the gene         Gene
# 1        chemical or drug increases the gene expression         Gene
# 2        chemical or drug increases the gene expression         Gene
# 3        chemical or drug increases the gene expression         Gene
# 4        chemical or drug decreases the gene expression         Gene
# ...                                                 ...          ...
# 1456462                    gene interacts with the gene         Gene
# 1456463                    gene interacts with the gene         Gene
# 1456464                    gene interacts with the gene         Gene
# 1456465                    gene interacts with the gene         Gene
# 1456466                    gene interacts with the gene         Gene
#
#                                                     target
# 0        {'typeOfGene': 'protein-coding', 'commonName':...
# 1        {'typeOfGene': 'protein-coding', 'commonName':...
# 2        {'typeOfGene': 'protein-coding', 'commonName':...
# 3        {'typeOfGene': 'protein-coding', 'commonName':...
# 4        {'typeOfGene': 'protein-coding', 'commonName':...
# ...                                                    ...
# 1456462  {'typeOfGene': 'protein-coding', 'commonName':...
# 1456463  {'typeOfGene': 'protein-coding', 'commonName':...
# 1456464  {'typeOfGene': 'protein-coding', 'commonName':...
# 1456465  {'typeOfGene': 'protein-coding', 'commonName':...
# 1456466  {'typeOfGene': 'protein-coding', 'commonName':...
#
# [1456467 rows x 5 columns]

# %%
combined_df.to_csv('alzkb_relationships_v2.csv', index=False)

# %%
combined_df.to_json('alzkb_relationships.json')
